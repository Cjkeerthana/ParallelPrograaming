# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import re

# %%
N12h_path = "/home/cjkeerthana/Documents/Parallel_Programming/ParallelProgramming/Ex5/MPI_FileDump/serial_IO/output/1200"
N12k_path = "/home/cjkeerthana/Documents/Parallel_Programming/ParallelProgramming/Ex5/MPI_FileDump/serial_IO/output/12000"
os.listdir(N12h_path)
os.listdir(N12k_path)
# Out:
# ['bin', 'hdf5', 'dat']

# %%
def read_text_file(file_path):
    with open(file_path, 'r') as f:
        time = 0
        for line in f.readlines():
                t = re.findall(r"[-+]?\d*\.\d+|\d+", line)
                time = time + float(t[1])
        return time

# %%
def read_all_times(dir_path):
    times = []
    for file in os.listdir(dir_path):
    # Check whether file is in text format or not
        if file.endswith(".txt"):
            file_path = dir_path + "/" + file 
            name = file.split("_")
            avg_time = read_text_file(file_path)
            avg_time = avg_time/int(name[0])
            times.append((int(name[0]),avg_time))
    times.sort()
    procs = []
    tempo = []
    for e in times:
        a,b = e
        procs.append(a)
        tempo.append(b)
    return tempo

# %%
def separate_times(totTime, commTime, calcTime, dumpTime):
    totTime = np.asarray(totTime)
    commTime = np.asarray(commTime)
    calcTime = np.asarray(calcTime)
    commTime = commTime - calcTime
    calcTime = totTime - dumpTime - commTime
    return totTime,commTime,calcTime,dumpTime

# %%
def make_plots_times(title, labels, commTime, calcTime, dumpTime):
    x = np.arange(len(labels))  # the label locations
    width = 0.35  # the width of the bars
    fig, ax = plt.subplots(figsize=(20, 10))
    rects1 = ax.bar(x, calcTime, width, label='CalcTime')
    rects2 = ax.bar(x, commTime, width, bottom=calcTime, label='CommTime')
    rects3 = ax.bar(x, dumpTime, width, bottom=calcTime+commTime, label='DumpTime')
    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_ylabel('Time')
    ax.set_xlabel('procs')
    ax.set_title(title ) 
    ax.set_xticks(x)
    ax.legend()
    ax.set_xticklabels(labels)

    fig.tight_layout()

    plt.show()

# %%
def make_plot_speedup(title, totTime,procs,labels, t_serial):
    speed_up = t_serial/totTime
    plt.figure(figsize=(10,5))
    plt.plot(procs,speed_up)
    plt.title("Speed Up" + " " + title)
    plt.ylabel("speed up")
    plt.xlabel("nodes")
    plt.xticks(procs)
    plt.show()

# %%
commTime = read_all_times(N12h_path + "/bin/commTime")
totTime = read_all_times(N12h_path + "/bin/totTime")
calcTime = read_all_times(N12h_path + "/bin/calcTime")
dumpTime = read_all_times(N12h_path + "/bin/dumpTime")
totTime, commTime, calcTime, dumpTime = separate_times(totTime, commTime, calcTime, dumpTime)
labels = ["20","40","80","160","320"]
procs = np.asarray([20,40,80,160,320])
title = "N1200 - Binary files"
make_plots_times(title,labels,commTime,calcTime, dumpTime)
make_plot_speedup(title, np.asarray(totTime), procs, labels, totTime[0])

# %%
commTime = read_all_times(N12h_path + "/dat/commTime")
totTime = read_all_times(N12h_path + "/dat/totTime")
calcTime = read_all_times(N12h_path + "/dat/calcTime")
dumpTime = read_all_times(N12h_path + "/dat/dumpTime")
totTime, commTime, calcTime, dumpTime = separate_times(totTime, commTime, calcTime, dumpTime)
labels = ["20","40","80","160","320"]
procs = np.asarray([20,40,80,160,320])
title = "N1200 - Dat files"
make_plots_times(title,labels,commTime,calcTime, dumpTime)
make_plot_speedup(title, np.asarray(totTime), procs, labels, totTime[0])

# %%
commTime = read_all_times(N12h_path + "/hdf5/commTime")
totTime = read_all_times(N12h_path + "/hdf5/totTime")
calcTime = read_all_times(N12h_path + "/hdf5/calcTime")
dumpTime = read_all_times(N12h_path + "/hdf5/dumpTime")
totTime, commTime, calcTime, dumpTime = separate_times(totTime, commTime, calcTime, dumpTime)
labels = ["20","40","80","160","320"]
procs = np.asarray([20,40,80,160,320])
title = "N1200 - HDF5 files"
make_plots_times(title,labels,commTime,calcTime, dumpTime)
make_plot_speedup(title, np.asarray(totTime), procs, labels, totTime[0])

# %%
commTime = read_all_times(N12k_path + "/bin/commTime")
totTime = read_all_times(N12k_path + "/bin/totTime")
calcTime = read_all_times(N12k_path + "/bin/calcTime")
dumpTime = read_all_times(N12k_path + "/bin/dumpTime")
totTime, commTime, calcTime, dumpTime = separate_times(totTime, commTime, calcTime, dumpTime)
labels = ["20","40","80","160","320"]
procs = np.asarray([20,40,80,160,320])
title = "N12000 - Binary files"
make_plots_times(title,labels,commTime,calcTime, dumpTime)
make_plot_speedup(title, np.asarray(totTime), procs, labels, totTime[0])

# %%
commTime = read_all_times(N12k_path + "/dat/commTime")
totTime = read_all_times(N12k_path + "/dat/totTime")
calcTime = read_all_times(N12k_path + "/dat/calcTime")
dumpTime = read_all_times(N12k_path + "/dat/dumpTime")
totTime, commTime, calcTime, dumpTime = separate_times(totTime, commTime, calcTime, dumpTime)
labels = ["20","40","80","160","320"]
procs = np.asarray([20,40,80,160,320])
title = "N12000 - Dat files"
make_plots_times(title,labels,commTime,calcTime, dumpTime)
make_plot_speedup(title, np.asarray(totTime), procs, labels, totTime[0])
# Out:
# [93.77605665 90.9775181  89.54653846 88.64289959 89.34814559]

# %%
commTime = read_all_times(N12k_path + "/hdf5/commTime")
totTime = read_all_times(N12k_path + "/hdf5/totTime")
calcTime = read_all_times(N12k_path + "/hdf5/calcTime")
dumpTime = read_all_times(N12k_path + "/hdf5/dumpTime")
totTime, commTime, calcTime, dumpTime = separate_times(totTime, commTime, calcTime, dumpTime)
labels = ["20","40","80","160","320"]
procs = np.asarray([20,40,80,160,320])
title = "N12000 - HDF5 files"
make_plots_times(title,labels,commTime,calcTime, dumpTime)
make_plot_speedup(title, np.asarray(totTime), procs, labels, totTime[0])

# %% [markdown]
# The binary files are an order of magnitude faster than the text file and also the size of text files is much higher than the binary files.
